# %% [markdown]
# # Load data

# %%
import MetaTrader5 as mt
import pandas as pd
import plotly.express as px
from datetime import datetime

# %%
mt.initialize()
# Out:
# True

# %%
login = 5005199849
password = "gyyekbo4"
server = "MetaQuotes-Demo"

mt.login(login, password, server)
# Out:
# True

# %%
account_info = mt.account_info()
print(account_info)
# Out:
# AccountInfo(login=5005199849, trade_mode=0, leverage=100, limit_orders=200, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=100000.0, credit=0.0, profit=0.0, equity=100000.0, margin=0.0, margin_free=100000.0, margin_level=0.0, margin_so_call=50.0, margin_so_so=30.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='abc abc', server='MetaQuotes-Demo', currency='USD', company='MetaQuotes Software Corp.')

# %%
data1 = pd.DataFrame(mt.copy_rates_range("EURUSD",mt.TIMEFRAME_D1,datetime(2021,4,1), datetime.now()))
data2 = pd.DataFrame(mt.copy_rates_range("GBPUSD",mt.TIMEFRAME_D1,datetime(2021,4,1), datetime.now()))
data3 = pd.DataFrame(mt.copy_rates_range("USDCHF",mt.TIMEFRAME_D1,datetime(2021,4,1), datetime.now()))

# %%
fig = px.line(data1, x=data1['time'], y = data1['close'])
fig.show()
# Out:
# <div>                            <div id="11b89ed2-6e7f-48eb-a605-9e01fb0ee9a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11b89ed2-6e7f-48eb-a605-9e01fb0ee9a9")) {                    Plotly.newPlot(                        "11b89ed2-6e7f-48eb-a605-9e01fb0ee9a9",                        [{"hovertemplate":"time=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1617235200,1617321600,1617580800,1617667200,1617753600,1617840000,1617926400,1618185600,1618272000,1618358400,1618444800,1618531200,1618790400,1618876800,1618963200,1619049600,1619136000,1619395200,1619481600,1619568000,1619654400,1619740800,1620000000,1
# ...

# %% [markdown]
# # Train model

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, GRU
import numpy as np

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
scaled_data1_price_change = scaler.fit_transform((data1['high'] - data1['close']).values.reshape(-1,1))
scaled_data2_price_change = scaler.fit_transform((data2['high'] - data2['close']).values.reshape(-1,1))
scaled_data3_price_change = scaler.fit_transform((data3['high'] - data3['close']).values.reshape(-1,1))

# %% [markdown]
# # Stock 1

# %%
# need change
scaled_data = scaled_data1_price_change


prediction_days = 60

x_train = []
y_train = []

for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x,0])
    y_train.append(scaled_data[x,0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential()
model.add(GRU(3, return_sequences=True, input_shape=(x_train.shape[1], 1) ))
model.add(GRU(3, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs = 50, batch_size =32)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 26ms/step - loss: 0.0951
# Epoch 2/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0640
# Epoch 3/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0459
# Epoch 4/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0368
# Epoch 5/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0341
# Epoch 6/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0335
# Epoch 7/50
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0336
# Epoch 8/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0335
# Epoch 9/50
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0334
# Epoch 10/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0335
# Epoch 11/50
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0333
# Epoch 12/50
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0332
# ...

# %%
model.save("models/price_of_change/rnn/EURUSD.h5")

# %% [markdown]
# # stock 2

# %%
# need change
scaled_data = scaled_data2_price_change


prediction_days = 60

x_train = []
y_train = []

for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x,0])
    y_train.append(scaled_data[x,0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential()
model.add(GRU(3, return_sequences=True, input_shape=(x_train.shape[1], 1) ))
model.add(GRU(3, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs = 50, batch_size =32)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 33ms/step - loss: 0.0769
# Epoch 2/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0587
# Epoch 3/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0450
# Epoch 4/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0358
# Epoch 5/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0304
# Epoch 6/50
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0272
# Epoch 7/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0260
# Epoch 8/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0256
# Epoch 9/50
# 9/9 [==============================] - 0s 24ms/step - loss: 0.0255
# Epoch 10/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0255
# Epoch 11/50
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0255
# Epoch 12/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0255
# ...

# %%
model.save("models/price_of_change/rnn/GBPUSD.h5")

# %% [markdown]
# # stock 3

# %%
# need change
scaled_data = scaled_data3_price_change


prediction_days = 60

x_train = []
y_train = []

for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x,0])
    y_train.append(scaled_data[x,0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential()
model.add(GRU(3, return_sequences=True, input_shape=(x_train.shape[1], 1) ))
model.add(GRU(3, return_sequences=False))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs = 50, batch_size =32)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 4s 29ms/step - loss: 0.0109
# Epoch 2/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0091
# Epoch 3/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0093
# Epoch 4/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0090
# Epoch 5/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0091
# Epoch 6/50
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0090
# Epoch 7/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0090
# Epoch 8/50
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0090
# Epoch 9/50
# 9/9 [==============================] - 0s 25ms/step - loss: 0.0090
# Epoch 10/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0090
# Epoch 11/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0090
# Epoch 12/50
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0090
# ...

# %%
model.save("models/price_of_change/rnn/USDCHF.h5")

# %% [markdown]
# # test next day

# %%
import datetime
from datetime import timedelta
import matplotlib.pyplot as plt

real_data = [x_train[len(x_train + 1) - prediction_days:len(x_train),0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

prediction = model.predict(real_data)
prediction = scaler.inverse_transform(prediction)
prediction
# Out:
# 1/1 [==============================] - 1s 680ms/step
# array([[0.00391739]], dtype=float32)

# %%
data3
# Out:
#            time     open     high      low    close  tick_volume  spread  \
# 0    1617235200  0.94349  0.94727  0.94044  0.94156        43834       1
# 1    1617321600  0.94154  0.94339  0.94049  0.94204        16971       1
# 2    1617580800  0.94169  0.94385  0.93540  0.93615        30407       1
# 3    1617667200  0.93611  0.93958  0.93027  0.93078        36028       1
# 4    1617753600  0.93076  0.93178  0.92682  0.92949        37012       1
# ..          ...      ...      ...      ...      ...          ...     ...
# 341  1658448000  0.96654  0.97040  0.95999  0.96104       110358       0
# 342  1658707200  0.96251  0.96602  0.96091  0.96431        77883       0
# 343  1658793600  0.96424  0.96676  0.96157  0.96277        66788       0
# 344  1658880000  0.96268  0.96593  0.95831  0.95948        82168       0
# 345  1658966400  0.95917  0.96047  0.95686  0.95725        42830       0
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# ...
